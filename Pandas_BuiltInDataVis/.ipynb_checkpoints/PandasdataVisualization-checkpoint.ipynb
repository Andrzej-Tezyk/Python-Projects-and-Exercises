# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline

# %%
dataframe1 = pd.read_csv('dataframe1', index_col=0)

# %%
dataframe1.head()
# Out:
#                    A         B         C         D
# 2019-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2019-01-02 -0.774984  0.157034 -0.882716 -2.253382
# 2019-01-03 -0.921037 -0.482943 -0.419100  0.478638
# 2019-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2019-01-05 -0.905980  1.778576  0.381920  0.291436

# %%
dataframe2 = pd.read_csv('dataframe2')

# %%
dataframe2.head()
# Out:
#           a         b         c         d
# 0  0.039262  0.218512  0.103423  0.952904
# 1  0.932283  0.041562  0.899125  0.922630
# 2  0.280504  0.008943  0.552808  0.292510
# 3  0.622212  0.242870  0.264021  0.444353
# 4  0.053829  0.520124  0.552264  0.190003

# %%
dataframe3 = pd.read_csv('dataframe3', index_col=0)

# %%
dataframe3.head()
# Out:
#                  b         c         d
# a
# 0.336232  0.327011  0.001020  0.401402
# 0.980265  0.831837  0.332288  0.036487
# 0.480383  0.686839  0.000735  0.346378
# 0.702106  0.307142  0.368608  0.674687
# 0.876602  0.131448  0.173931  0.321231

# %%
dataframe1['A'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
dataframe1['A'].plot(kind='hist', bins=30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
dataframe1['A'].plot.hist(bins=30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
dataframe2.plot.area(alpha=0.5)
# Out:
# <AxesSubplot:>

# %%
dataframe2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
dataframe1['A'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
dataframe1.plot.line(y='B', figsize=(10,4), lw=1)
# Out:
# <AxesSubplot:>

# %%
dataframe1.plot.scatter(x='A', y='B', c='C', cmap='coolwarm')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
dataframe1.head()
# Out:
#                    A         B         C         D
# 2019-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2019-01-02 -0.774984  0.157034 -0.882716 -2.253382
# 2019-01-03 -0.921037 -0.482943 -0.419100  0.478638
# 2019-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2019-01-05 -0.905980  1.778576  0.381920  0.291436

# %%
dataframe1.plot.scatter(x='A', y='B', c='C', s=dataframe1['C'])
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
dataframe2.plot.box()
# Out:
# <AxesSubplot:>

# %%
dataframe = pd.DataFrame(np.random.randn(1000,2), columns=['A', 'B'])

# %%
dataframe.head()
# Out:
#           A         B
# 0  0.631267  2.033687
# 1  0.584219 -0.677244
# 2 -2.169783  0.214299
# 3  0.474473  0.915063
# 4  0.440609 -1.956415

# %%
dataframe.plot.hexbin(x='A', y='B', gridsize=30, cmap='coolwarm')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
dataframe2['a'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
dataframe2['a'].plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
dataframe2.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>
